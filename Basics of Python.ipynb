# %% [markdown]
# Exercise 1: Prime Numbers
#
#
#
#
#
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
def is_prine(n):
  if n <= 1:
    return False
  for i in range (2,n):
    if n % i == 0:
      return False
  return True
n = int(input("Enter a number: "))
if is_prine(n):
  print(f"{n} is prime")
else:
  print(f"{n} is not prime")
# Out:
# Enter a number: 6
# 6 is not prime

# %% [markdown]
# Exercise 2: Product of Random Numbers
#
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random

n1 = random.randint(1, 10)
n2 = random.randint(1, 10)

correct_answer = n1 * n2

print(f"What is {n1} * {n2}?")
user_answer = int(input("Your Answer: "))

if user_answer == correct_answer:
  print("Correct")
else:
  print(f"Wrong, The correct answer is {correct_answer}")
# Out:
# What is 5 * 4?
# Your Answer: 20
# Correct

# %% [markdown]
# Exercise 3: Squares of Even/Odd Numbers
#
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
print("Square of all even numbers from 100 to 200:")
for n in range(100, 201):
  if n % 2 == 0:
    print(f"{n}^2 = {n ** 2}")
# Out:
# Square of all even numbers from 100 to 200:
# 100^2 = 10000
# 102^2 = 10404
# 104^2 = 10816
# 106^2 = 11236
# 108^2 = 11664
# 110^2 = 12100
# 112^2 = 12544
# 114^2 = 12996
# 116^2 = 13456
# 118^2 = 13924
# 120^2 = 14400
# 122^2 = 14884
# 124^2 = 15376
# 126^2 = 15876
# 128^2 = 16384
# 130^2 = 16900
# 132^2 = 17424
# 134^2 = 17956
# 136^2 = 18496
# 138^2 = 19044
# 140^2 = 19600
# 142^2 = 20164
# 144^2 = 20736
# 146^2 = 21316
# 148^2 = 21904
# 150^2 = 22500
# 152^2 = 23104
# 154^2 = 23716
# 156^2 = 24336
# 158^2 = 24964
# 160^2 = 25600
# 162^2 = 26244
# 164^2 = 26896
# 166^2 = 27556
# 168^2 = 28224
# 170^2 = 28900
# 172^2 = 29584
# 174^2 = 30276
# 176^2 = 30976
# 178^2 = 31684
# 180^2 = 32400
# 182^2 = 33124
# 184^2 = 33856
# 186^2 = 34596
# 188^2 = 35344
# 190^2 = 36100
# 192^2 = 36864
# 194^2 = 37636
# 196^2 = 38416
# 198^2 = 39204
# 200^2 = 40000

# %% [markdown]
# Exercise 4:
# ✅ Problem Statement (Question): Hospital Billing System
#
# A hospital charges its patients based on the following:
#
# •	Room charges per day: ₹2,000
#
# •	Doctor consultation fee (flat): ₹1,500
#
# •	Lab test charges: Based on the number of tests taken. Each test costs ₹300
#
# •	Medicine charges: Total cost of medicines provided
#
# •	Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
#
# Write a Python program to calculate the final bill for a patient who:
#
# •	Stayed for 4 days
#
# •	Had 3 lab tests
#
# •	Had medicine charges of ₹2,400

# %%
Room_Charges = 2000
Consultation_Fee = 1500
Lab_Test_Cost = 300

days_stayed = 4
lab_test = 3
medicine_charges = 2400

Total_Room_Charges = days_stayed * Room_Charges
Total_Lab_Charges = lab_test * Lab_Test_Cost

Total = Total_Room_Charges + Consultation_Fee + Total_Lab_Charges + medicine_charges

if Total > 10000:
  discount = Total * 0.10
else:
  discount = 0

Final_Bill = Total - discount

print(f"Room cherges ({days_stayed} days): {Total_Room_Charges}")
print(f"Consultation Fee: {Consultation_Fee}")
print(f"Lab Test Charges ({lab_test} tests): {Total_Lab_Charges}")
print(f"Medicine Charges: {medicine_charges}")
print(f"Total: {Total}")
print(f"Discount: {discount}")
# Out:
# Room cherges (4 days): 8000
# Consultation Fee: 1500
# Lab Test Charges (3 tests): 900
# Medicine Charges: 2400
# Total: 12800
# Discount: 1280.0
